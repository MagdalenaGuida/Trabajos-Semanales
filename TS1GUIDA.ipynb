# %% [markdown]
# # Trabajo Semanal N°1
# ### Alumno: Magdalena Guida
#
# Se diseño una señal senoidal con las siguientes variables a parametrizar:
# - Amplitud (V_max) [Volts]
# - Valor medio (dc) [Volts]
# - Frecuencia (frec) [Hz]
# - Fase (ph) [rad]
# - Cantidad de muestras digitalizadas (nn)
# - Frecuencia de muestreo (fs) [Hz]

# %%
import numpy as np
import matplotlib.pyplot as plt

fs =1000 # Frecuencia de muestreo
N = 1000   # Número de muestras
ts = 1 / fs  # Tiempo de muestreo
df = fs / N  # Resolución espectral    

# Definir funciónes seno
def func_sen(V_max=1, dc=0, frec=1, ph=0, nn=N, fs=fs):
    
    tt = np.arange(0, nn / fs, 1 / fs).flatten()
    
    xx = V_max * np.sin(2 * np.pi * frec * tt + ph).flatten() + dc
    
    return tt, xx

tt1, xx1 = func_sen(frec=1, fs=fs)
tt2, xx2 = func_sen(frec=10, fs=fs)
tt3, xx3 = func_sen(frec=2000, fs=fs)

# %% [markdown]
# Se definio una funcion senoidal generica a la cual se le aplicaron tres frecuencias distitas frec1 = 1Hz, frec2 = 50 Hz y frec3 = 2000Hz para una misma frecuencia de muestreo fs = 1000Hz. Sabiendo que la Teoria de Muestreo pide una frecuencia de muestreo fs estrictamente mayor a la frecuencia de la señal, es evidente que frec3 no cumple por la condicion por lo que no se toman suficientes muestras de esta señal para llegar a reproducirla correctamente.

# %%
# Caracteristicas del Grafico
plt.title("Señales Senoidales")
plt.plot(tt1, xx1, label="Frecuencia = 1 Hz", color = 'b')
plt.plot(tt2, xx2, label="Frecuencia = 10 Hz", color = 'r')
plt.plot(tt3, xx3, label="Frecuencia = 2000 Hz", color = 'y')
plt.legend(loc = 'lower left')
plt.xlabel("Tiempo [segundos]")
plt.ylabel("Amplitud [Volts]")
plt.grid(True)
plt.show()

# %% [markdown]
# Asi como se esperaba, la señal amarilla (frec3), no pudo ser representada.
